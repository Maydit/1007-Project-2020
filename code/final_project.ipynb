# %%
from datetime import datetime
from dateutil import parser
import calendar

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as plticker

import itertools
import math

import re
import nltk
import os
from collections import Counter

# %%
## Get list of stopwords from NLTK package
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\preston\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# # Functions

# %% [markdown]
# ### Cleaning and variable creation

# %%
def clean_tweets(df, startdate = 20200811, no_stops = True):
    '''
    Purpose:
    -------
    Cleans up tweets for easier parsing throughout script.
    Cleaning includes removing unnecessary characters like URLS, punctuation, digits,
    and words with two or fewer characters.
    English stop words and words with two or fewer characters may also be optionally removed.
    
    Inputs:
    ------
    df - dataframe containing "id", "date", "month", and "tweet" columns
    
    startdate - earliest date in outputted dataframe (all earlier dates are dropped)
                
    no_stops - if True, remove stop words from tweets
    
    '''
    
    ## Define dataframe and filter by date
    df = df[['id', 'date', 'month', 'tweet']]
    df = df[df.index > parser.parse(str(startdate))]
    
    ## Clean tweets
    clean_text = []

    for tweet in df.tweet:
        # Remove URLS
        tweet = re.sub("(\w+:\/\/\S+)", " ", tweet)
        # Replace non-characters with spaces
        tweet = re.sub("\W", " ", tweet)
        # Remove digits
        tweet = re.sub("[0-9]", "", tweet)
        # Remove words with two or fewer characters
        tweet = re.sub("(?<= )[A-Za-z]{1,2}(?= )", "", tweet)
        tweet = re.sub("^[A-Za-z]{1,2}\s", "", tweet)
        tweet = re.sub("\s[A-Za-z]{1,2}$", "", tweet)
        # Remove extra spaces
        tweet = re.sub("\s+", " ", tweet)
        tweet = re.sub("^\s+", "", tweet)
        tweet = re.sub("\s+$", "", tweet)
            
        clean_text.append(tweet.lower())

    ## Add updated text to main data
    df['clean_text'] = clean_text
    df['term_list'] = df['clean_text'].apply(lambda x: x.split())
    
    ## Remove stop words from tweets
    if no_stops == True:
        stop_words = nltk.corpus.stopwords.words('english')
        
        stopless_terms = []
        for term_list in df['term_list']:
            stopless_terms.append(list(np.setdiff1d(term_list, stop_words)))

        df['term_list'] = stopless_terms
    
    return df

# %%
def computeTF(x):
    '''
    Purpose:
    -------
    Generates a counter object (dictionary like) associating a term present
    in a document with its normalized frequncy.
    Helper fucntion for the TF-IDF calculation.
    
    Inputs:
    ------
    x - 2-dimentional array like object containing the list of all terms in
        the 0-index and a collection object containing the term counts in the 1-index

    '''  
    wordFreq = x[1]
    wordList = x[0]
    bagOfWordsCount = len(wordList)
    
    tfDict = {}
    for word, count in wordFreq.items():
        tfDict[word] = count / float(bagOfWordsCount)
        
    return Counter(tfDict)

# %%
def term_counter(txt_list):
    '''
    Purpose:
    -------
    Generates and returns a counter object (dictionary-like) of the counts of
    each unique term from a list of terms.  The keys of the dictionary are the
    unique terms and the values are the counts of that term.
    Helper fucntion for the TF-IDF calculation.
    
    Inputs:
    ------
    x - list of string values

    '''
    term_counts = {}
    for i in set(txt_list):
        term_counts[i] = txt_list.count(i)
        
    return(Counter(term_counts))

# %%
def return_term_count_list(df, term_count_column = "term_count"):
    '''
    Purpose:
    -------
    Generates and returns a list of all frequncy count counter objects (dictionary like)
    from a data frame column containing frequency count objects.
    Helper fucntion for the TF-IDF calculation.
    
    Inputs:
    ------
    df - dataframe containing column with frequency counts as counter objects as entries
        
    term_count_column - name of columns containing frequency counts
    
    '''
    term_count_list = []
    for i in df[term_count_column]:
        term_count_list.append(dict(i))
        
    return(term_count_list)

# %%
def return_corpus_set(df, term_list_column = "term_list"):
    '''
    Purpose:
    -------
    Generates and returns a set of all unique terms found across the union of all
    documnets (the corpus).
    Helper fucntion for the TF-IDF calculation.
    
    Inputs:
    ------
    df - dataframe containing column with frequency counts as counter objects as entries
        
    term_count_column - name of column containing frequency counts
    
    '''     
    tweet_corpus = []
    for i in df[term_list_column]:
        tweet_corpus += i

    return(set(tweet_corpus))

# %%
def computeIDF(documents, corpus_set):
    '''
    Purpose:
    -------
    Generates the inverse document frequency score (IDF) for all terms in the corpus.
    Helper fucntion for the TF-IDF calculation.
    
    Inputs:
    ------
    documents - list of counter objects containing the frequency counts for each document
        
    corpus_set - set of all unique terms found across the union of all documnets (the corpus)
    
    '''  
    N = len(documents)

    idfDict = dict.fromkeys(corpus_set, 0)
    for document in documents:
        for word, val in document.items():
            if val > 0:
                idfDict[word] += 1

    for word, val in idfDict.items():
        idfDict[word] = math.log(N / (float(val)))
        
    return(Counter(idfDict))

# %%
def computeTFIDF(TF,idfs):
    '''
    Purpose:
    -------
    Generates the term frequency/inverse document frequency (TF-IDF score) for each
    unique term in a document.
    
    Inputs:
    ------
    TF - Counter object containing the term frequncy values for each document
        
    idfs - Counter object containing the inverse document frequency score (IDF) for
           all terms unqiue in the corpus
    
    '''
    tfidf = {}
    for word, val in TF.items():
        tfidf[word] = val * idfs[word]
        
    return(Counter(tfidf))

# %%
def TFIDF_processing(df):      
    '''
    Purpose:
    -------
    Uses the associated helper functions to calculate the TF-IDF scores for a dataframe of documents.
    Returns a 3-dimentional array containing:
        - [0] a data frame with the TF-IDF scores, TF scores, term-list, processed document, and term count.
        - [1] the idf scores for all terms in the corpus
        - [2] the corpus of the document
    
    Inputs:
    ------
    df - dataframe of processed documents
    
    '''
    df = clean_tweets(df)

    # Create dictionary of term counts for each tweet
    df['term_count'] = df['term_list'].apply(lambda x: term_counter(x))
    
    # Calculate term frequency (TF)
    df['TF'] = df[['term_list', 'term_count']].apply(computeTF, axis = 1)
    
    # Return corpus and doc list
    term_count_list_df = return_term_count_list(df)
    corpus_set_df = return_corpus_set(df)
    
    # Calculate IDF and  TF-IDF
    df_idf = computeIDF(term_count_list_df, corpus_set_df)
    df['TFIDF'] = df['TF'].apply(lambda x: computeTFIDF(x, df_idf))
    
    return(df, df_idf, corpus_set_df)

# %% [markdown]
# ### TFIDF organization

# %%
def sum_normalize_collections(counter_list):
    '''
    Purpose:
    -------
    Generates an aggregate tfidf score counter object from a list of counter objects.
    Takes the sum of all TF_IDF scores with respect to term objects and then divides
    by the number of dictionaries in the list.
    
    Inputs:
    ------
    counter_list - list of counter objects that contain TF-IDF scores
    
    '''
    counter_sum = Counter()
    for counter in counter_list:
        counter_sum += counter
        
    for k,v in counter_sum.items():
        counter_sum[k] = v/len(counter_list)
        
    return(counter_sum.most_common())

# %%
def TFIDF_vecorization(df,corpus):
    '''
    Purpose:
    -------
    Vecotrizes the tf-idf scores.  Not advised.
    
    Inputs:
    ------
    df - dataframe with tf-idf scores
    corpus - set of unique words across all documents
    
    '''
    D = np.zeros((len(df), len(corpus)))

    for i,tfidf in enumerate(df["TFIDF"]):
        for term in tfidf:
            ind = (list(corpus)).index(term)
            D[i][ind] = tfidf[term]
            
    return(D)

# %%
def get_day_tfidf(df, date):
    '''
    Purpose:
    -------
    Takes full dataframe containing tf-idf scores and returns a dataframe with
    each word and its tf-idf score for a particular date
    
    Inputs:
    ------
    df - cleaned dataframe with tf-idf scores
    
    date - day for which tf-idf scores should be returned
           date format: 'YYYY-MM-DD'
    
    '''
    day = pd.DataFrame(df.loc[date][0])
    idx = pd.DatetimeIndex([date] * len(day))
    
    day.index = idx
    day.columns = ['words', 'TFIDF']
    
    return(day)

# %%
def movingaverage (values, window):
    '''
    Purpose:
    -------
    Calculate a rolling average over a set of values.
    The rolling average for the ith value is the mean of all values
    between index (i - j) and index i where 'j' is the size of the 'window'
    
    Inputs:
    ------
    values - a set of values for which to calculate rolling averages (length must be
             greater than window)
    
    window - range over which rolling averages are calculated
    
    '''
    weights = np.repeat(1.0, window) / window
    
    sma = np.convolve(values, weights, 'valid')
    
    return sma

# %% [markdown]
# ---

# %% [markdown]
# # Data

# %% [markdown]
# ## Twitter Data

# %%
## Import Biden data
biden_df = pd.read_csv('../data/biden.csv', index_col = 'date', parse_dates = True)
biden_df.index.rename("datetime", inplace = True)

## Date variables
biden_df['date'] = biden_df.index.date
biden_df['month'] = biden_df.index.month

biden_df.head()
# Out:
#                      Unnamed: 0                   id      conversation_id  \
# datetime
# 2020-11-09 14:40:00           0  1325885871875190784  1325885871875190784
# 2020-11-09 14:17:00           1  1325880083618426881  1325880083618426881
# 2020-11-09 13:50:00           2  1325873288711712769  1325873288711712769
# 2020-11-09 13:37:00           3  1325870017401905152  1325870017401905152
# 2020-11-09 11:46:50           4  1325842292444291072  1325842292444291072
#
#                        created_at  timezone  place  \
# datetime
# 2020-11-09 14:40:00  1.604951e+12      -500    NaN
# 2020-11-09 14:17:00  1.604949e+12      -500    NaN
# 2020-11-09 13:50:00  1.604948e+12      -500    NaN
# 2020-11-09 13:37:00  1.604947e+12      -500    NaN
# 2020-11-09 11:46:50  1.604940e+12      -500    NaN
#
#                                                                  tweet  \
# datetime
# 2020-11-09 14:40:00  The bottom line: I will spare no effort to tur...
# 2020-11-09 14:17:00  The challenge before us right now is still imm...
# 2020-11-09 13:50:00  My COVID-19 Transition Advisory Board will adv...
# 2020-11-09 13:37:00  Today, I have named a COVID-19 Transition Advi...
# 2020-11-09 11:46:50  I spent the morning with the co-chairs of my C...
#
#                     language hashtags cashtags  ...  user_rt_id  user_rt  \
# datetime                                        ...
# 2020-11-09 14:40:00       en       []       []  ...         NaN      NaN
# 2020-11-09 14:17:00       en       []       []  ...         NaN      NaN
# 2020-11-09 13:50:00       en       []       []  ...         NaN      NaN
# 2020-11-09 13:37:00       en       []       []  ...         NaN      NaN
# 2020-11-09 11:46:50       en       []       []  ...         NaN      NaN
#
#                     retweet_id reply_to  retweet_date  translate trans_src  \
# datetime
# 2020-11-09 14:40:00        NaN       []           NaN        NaN       NaN
# 2020-11-09 14:17:00        NaN       []           NaN        NaN       NaN
# 2020-11-09 13:50:00        NaN       []           NaN        NaN       NaN
# 2020-11-09 13:37:00        NaN       []           NaN        NaN       NaN
# 2020-11-09 11:46:50        NaN       []           NaN        NaN       NaN
#
#                     trans_dest        date  month
# datetime
# 2020-11-09 14:40:00        NaN  2020-11-09     11
# 2020-11-09 14:17:00        NaN  2020-11-09     11
# 2020-11-09 13:50:00        NaN  2020-11-09     11
# 2020-11-09 13:37:00        NaN  2020-11-09     11
# 2020-11-09 11:46:50        NaN  2020-11-09     11
#
# [5 rows x 40 columns]

# %%
## Import Trump data
trump_df = pd.read_csv('../data/trump.csv', index_col = 'date', parse_dates = True)
trump_df.index.rename("datetime", inplace = True)

## Date variables
trump_df['date'] = trump_df.index.date
trump_df['month'] = trump_df.index.month

## Match variable names to Trump
trump_df.rename(columns = {'text' : 'tweet'}, inplace = True)

trump_df.head()
# Out:
#                                       id  \
# datetime
# 2011-08-02 18:07:48    98454970654916608
# 2020-03-03 01:34:50  1234653427789070336
# 2020-01-17 03:22:47  1218010753434820614
# 2020-09-12 20:10:58  1304875170860015617
# 2020-01-17 13:13:59  1218159531554897920
#
#                                                                  tweet  \
# datetime
# 2011-08-02 18:07:48  Republicans and Democrats have both created ou...
# 2020-03-03 01:34:50  I was thrilled to be back in the Great city of...
# 2020-01-17 03:22:47  RT @CBS_Herridge: READ: Letter to surveillance...
# 2020-09-12 20:10:58  The Unsolicited Mail In Ballot Scam is a major...
# 2020-01-17 13:13:59  RT @MZHemingway: Very friendly telling of even...
#
#                     isRetweet isDeleted              device  favorites  \
# datetime
# 2011-08-02 18:07:48         f         f           TweetDeck         49
# 2020-03-03 01:34:50         f         f  Twitter for iPhone      73748
# 2020-01-17 03:22:47         t         f  Twitter for iPhone          0
# 2020-09-12 20:10:58         f         f  Twitter for iPhone      80527
# 2020-01-17 13:13:59         t         f  Twitter for iPhone          0
#
#                      retweets        date  month
# datetime
# 2011-08-02 18:07:48       255  2011-08-02      8
# 2020-03-03 01:34:50     17404  2020-03-03      3
# 2020-01-17 03:22:47      7396  2020-01-17      1
# 2020-09-12 20:10:58     23502  2020-09-12      9
# 2020-01-17 13:13:59      9081  2020-01-17      1

# %% [markdown]
# ### Process Twitter data

# %%
## Calculate TFIDFs for Biden
biden_df, biden_idf,biden_corpus = TFIDF_processing(biden_df)
biden_df.head()
# Out:
#                                       id        date  month  \
# datetime
# 2020-11-09 14:40:00  1325885871875190784  2020-11-09     11
# 2020-11-09 14:17:00  1325880083618426881  2020-11-09     11
# 2020-11-09 13:50:00  1325873288711712769  2020-11-09     11
# 2020-11-09 13:37:00  1325870017401905152  2020-11-09     11
# 2020-11-09 11:46:50  1325842292444291072  2020-11-09     11
#
#                                                                  tweet  \
# datetime
# 2020-11-09 14:40:00  The bottom line: I will spare no effort to tur...
# 2020-11-09 14:17:00  The challenge before us right now is still imm...
# 2020-11-09 13:50:00  My COVID-19 Transition Advisory Board will adv...
# 2020-11-09 13:37:00  Today, I have named a COVID-19 Transition Advi...
# 2020-11-09 11:46:50  I spent the morning with the co-chairs of my C...
#
#                                                             clean_text  \
# datetime
# 2020-11-09 14:40:00  the bottom line will spare effort turn this pa...
# 2020-11-09 14:17:00  the challenge before right now still immense a...
# 2020-11-09 13:50:00  covid transition advisory board will advise de...
# 2020-11-09 13:37:00  today have named covid transition advisory boa...
# 2020-11-09 11:46:50  spent the morning with the chairs covid counci...
#
#                                                              term_list  \
# datetime
# 2020-11-09 14:40:00  [around, bottom, effort, line, pandemic, spare...
# 2020-11-09 14:17:00  [action, bold, challenge, fight, growing, imme...
# 2020-11-09 13:50:00  [advise, advisory, american, bedrock, board, b...
# 2020-11-09 13:37:00  [advisory, biden, blueprint, board, comprised,...
# 2020-11-09 11:46:50  [beat, chairs, council, covid, discussing, for...
#
#                                                             term_count  \
# datetime
# 2020-11-09 14:40:00  {'around': 1, 'effort': 1, 'bottom': 1, 'spare...
# 2020-11-09 14:17:00  {'challenge': 1, 'immense': 1, 'need': 1, 'sti...
# 2020-11-09 13:50:00  {'covid': 1, 'transition': 1, 'core': 1, 'advi...
# 2020-11-09 13:37:00  {'sworn': 1, 'experts': 1, 'distinguished': 1,...
# 2020-11-09 11:46:50  {'forward': 1, 'covid': 1, 'going': 1, 'tune':...
#
#                                                                     TF  \
# datetime
# 2020-11-09 14:40:00  {'around': 0.14285714285714285, 'effort': 0.14...
# 2020-11-09 14:17:00  {'challenge': 0.1, 'immense': 0.1, 'need': 0.1...
# 2020-11-09 13:50:00  {'covid': 0.058823529411764705, 'transition': ...
# 2020-11-09 13:37:00  {'sworn': 0.041666666666666664, 'experts': 0.0...
# 2020-11-09 11:46:50  {'forward': 0.0625, 'covid': 0.0625, 'going': ...
#
#                                                                  TFIDF
# datetime
# 2020-11-09 14:40:00  {'around': 0.5783739832295148, 'effort': 0.821...
# 2020-11-09 14:17:00  {'challenge': 0.5193750186909607, 'immense': 0...
# 2020-11-09 13:50:00  {'covid': 0.17264515979846784, 'transition': 0...
# 2020-11-09 13:37:00  {'sworn': 0.29748584733187167, 'experts': 0.20...
# 2020-11-09 11:46:50  {'forward': 0.2859194361564614, 'covid': 0.183...

# %%
## Calculate TFIDF scores by date for Biden
biden_by_date = biden_df.groupby("date")["TFIDF"].apply(lambda x:x.to_list())

score_df_biden = pd.DataFrame(biden_df.groupby("date")["TFIDF"].apply(lambda x: sum_normalize_collections(x.to_list())))
score_df_biden.index = pd.DatetimeIndex(score_df_biden.index)

score_df_biden.head()
# Out:
#                                                         TFIDF
# date
# 2020-08-11  [(win, 0.23110318459999188), (kamalaharris, 0....
# 2020-08-12  [(kamalaharris, 0.15188697536226878), (let, 0....
# 2020-08-13  [(days, 0.3480363500813832), (kamalaharris, 0....
# 2020-08-14  [(security, 0.22304291398143478), (social, 0.2...
# 2020-08-15  [(kamalaharris, 0.1095714028560572), (vice, 0....

# %%
## Calculate TFIDF scores by month for Biden
biden_by_month = biden_df.groupby("month")["TFIDF"].apply(lambda x:x.to_list())

score_df_biden_mo = pd.DataFrame(biden_df.groupby("month")["TFIDF"].apply(lambda x: sum_normalize_collections(x.to_list())))

score_df_biden_mo.head()
# Out:
#                                                    TFIDF
# month
# 8      [(demconvention, 0.04782760160147074), (kamala...
# 9      [(trump, 0.03863101009907329), (president, 0.0...
# 10     [(vote, 0.04553566707673489), (days, 0.0409985...
# 11     [(vote, 0.06595624315145338), (let, 0.03765882...

# %%
## Calculate TFIDFs for Trump
trump_df, trump_idf, trump_corpus = TFIDF_processing(trump_df)
trump_df.head()
# Out:
#                                       id        date  month  \
# datetime
# 2020-09-12 20:10:58  1304875170860015617  2020-09-12      9
# 2020-10-23 22:04:14  1319761576996573186  2020-10-23     10
# 2020-10-12 22:22:39  1315779944002199552  2020-10-12     10
# 2020-10-23 19:50:48  1319727996882702336  2020-10-23     10
# 2020-10-23 19:49:55  1319727773234069505  2020-10-23     10
#
#                                                                  tweet  \
# datetime
# 2020-09-12 20:10:58  The Unsolicited Mail In Ballot Scam is a major...
# 2020-10-23 22:04:14  THANK YOU to all of the Great American Patriot...
# 2020-10-12 22:22:39  “I’m running as a proud Democrat, for the Sena...
# 2020-10-23 19:50:48                            https://t.co/LCQcdlRkhz
# 2020-10-23 19:49:55                            https://t.co/4V7nu5hh8V
#
#                                                             clean_text  \
# datetime
# 2020-09-12 20:10:58  the unsolicited mail ballot scam major threat ...
# 2020-10-23 22:04:14  thank you all the great american patriots the ...
# 2020-10-12 22:22:39  running proud democrat for the senate sleepy j...
# 2020-10-23 19:50:48
# 2020-10-23 19:49:55
#
#                                                              term_list  \
# datetime
# 2020-09-12 20:10:58  [almost, amp, ballot, ballots, count, democrac...
# 2020-10-23 22:04:14  [american, florida, great, maga, patriots, tha...
# 2020-10-12 22:22:39  [biden, china, county, democrat, get, going, j...
# 2020-10-23 19:50:48                                                 []
# 2020-10-23 19:49:55                                                 []
#
#                                                             term_count  \
# datetime
# 2020-09-12 20:10:58  {'fewer': 1, 'democrats': 1, 'democracy': 1, '...
# 2020-10-23 22:04:14  {'villages': 1, 'great': 1, 'thank': 1, 'flori...
# 2020-10-12 22:22:39  {'county': 1, 'going': 1, 'running': 1, 'sleep...
# 2020-10-23 19:50:48                                                 {}
# 2020-10-23 19:49:55                                                 {}
#
#                                                                     TF  \
# datetime
# 2020-09-12 20:10:58  {'fewer': 0.034482758620689655, 'democrats': 0...
# 2020-10-23 22:04:14  {'villages': 0.14285714285714285, 'great': 0.1...
# 2020-10-12 22:22:39  {'county': 0.07142857142857142, 'going': 0.071...
# 2020-10-23 19:50:48                                                 {}
# 2020-10-23 19:49:55                                                 {}
#
#                                                                  TFIDF
# datetime
# 2020-09-12 20:10:58  {'fewer': 0.2782531850624702, 'democrats': 0.1...
# 2020-10-23 22:04:14  {'villages': 1.152763195258805, 'great': 0.352...
# 2020-10-12 22:22:39  {'county': 0.4051033638580903, 'going': 0.2633...
# 2020-10-23 19:50:48                                                 {}
# 2020-10-23 19:49:55                                                 {}

# %%
## Calculate TFIDF scores by date for Trump
trump_by_date = trump_df.groupby("date")["TFIDF"].apply(lambda x:x.to_list())

score_df_trump = pd.DataFrame(trump_df.groupby("date")["TFIDF"].apply(lambda x: sum_normalize_collections(x.to_list())))
score_df_trump.index = pd.DatetimeIndex(score_df_trump.index)

score_df_trump.head()
# Out:
#                                                         TFIDF
# date
# 2020-08-11  [(conference, 0.18394266517168603), (news, 0.1...
# 2020-08-12  [(usdot, 0.19586578800958493), (bus, 0.1856589...
# 2020-08-13  [(realdonaldtrump, 0.21213159558160644), (cham...
# 2020-08-14  [(katrinapierson, 0.07832280986678118), (thank...
# 2020-08-15  [(lizrnc, 0.22264178117026823), (terrible, 0.1...

# %%
## Calculate TFIDF scores by month for Trump
trump_by_month = trump_df.groupby("month")["TFIDF"].apply(lambda x:x.to_list())

score_df_trump_mo = pd.DataFrame(trump_df.groupby("month")["TFIDF"].apply(lambda x: sum_normalize_collections(x.to_list())))

score_df_trump_mo.head()
# Out:
#                                                    TFIDF
# month
# 8      [(thank, 0.04571654981620453), (realdonaldtrum...
# 9      [(thank, 0.05418582656476436), (realdonaldtrum...
# 10     [(thank, 0.05470784714325705), (vote, 0.041431...

# %% [markdown]
# score_df_joe.to_csv('../../data/biden_tweet_scores.csv')
# score_df_donald.to_csv('../../data/trump_tweet_scores.csv')

# %% [markdown]
# ## Polling Data

# %% [markdown]
# ### Pull polling data

# %%
# Read in data, select relevant cols
cols = ['poll_id', 'fte_grade', 'sample_size', 'start_date', 'answer', 'pct']
ge = pd.read_csv('../data/president_polls.csv', usecols = cols, index_col = 'start_date', parse_dates = True)

# %% [markdown]
# ### Clean polling data

# %%
# Only use good polls (according to 538)
ge = ge[ge['fte_grade'].isin(['A+', 'A', 'A-', 'A/B', 'B+', 'B'])]
ge.drop('fte_grade', axis = 1, inplace = True)

# %%
# Check to see the latest date with primary candidates still.
lastdate = ge[ge['answer'] == 'Sanders'].index.values[0]

# %%
# Drop all primary dates, only need Biden and Trump
ge = ge[ge.index > lastdate]
ge = ge[ge.answer.isin(['Biden', 'Trump'])]

# %%
# Use a pivot table to get Biden and Trump pct in the same row
runoff = ge.pivot_table('pct', ['start_date', 'poll_id', 'sample_size'], 'answer').reset_index().set_index('start_date')
runoff
# Out:
# answer      poll_id  sample_size  Biden  Trump
# start_date
# 2020-04-10    65918       1200.0   44.0   49.0
# 2020-04-12    65756       1166.0   48.0   43.0
# 2020-04-13    65781        900.0   49.0   42.0
# 2020-04-14    65761       1318.0   48.0   47.0
# 2020-04-16    65841       1385.0   46.0   42.0
# ...             ...          ...    ...    ...
# 2020-10-30    72619       1501.0   49.0   41.0
# 2020-10-31    72714       1363.0   53.0   43.0
# 2020-10-31    72714       1500.0   49.0   40.0
# 2020-11-01    72621        871.0   49.0   48.0
# 2020-11-01    72661        500.0   46.0   50.1
#
# [650 rows x 4 columns]

# %%
# Weight percentages by sample sizes
runoff['total_biden'] = runoff['Biden'] * runoff['sample_size']
runoff['total_trump'] = runoff['Trump'] * runoff['sample_size']

election_cleaned = runoff.groupby('start_date')[['sample_size', 'total_biden', 'total_trump']].sum().sort_index()
election_cleaned['w_biden'] = election_cleaned['total_biden'] / election_cleaned['sample_size']
election_cleaned['w_trump'] = election_cleaned['total_trump'] / election_cleaned['sample_size']
election_cleaned.head()
# Out:
# answer      sample_size  total_biden  total_trump    w_biden    w_trump
# start_date
# 2020-04-10       1200.0      52800.0      58800.0  44.000000  49.000000
# 2020-04-12       1166.0      55968.0      50138.0  48.000000  43.000000
# 2020-04-13        900.0      44100.0      37800.0  49.000000  42.000000
# 2020-04-14       1318.0      63264.0      61946.0  48.000000  47.000000
# 2020-04-16       2020.0      98000.0      82300.0  48.514851  40.742574

# %% [markdown]
# ---

# %% [markdown]
# # Figures

# %%
## Find month names for labelling
months = election_cleaned.index.month

month_names = [calendar.month_name[m] for m in set(months)]
month_names
# Out:
# ['April', 'May', 'June', 'July', 'August', 'September', 'October', 'November']

# %%
np.arange(len(election_cleaned), step = len(election_cleaned)/len(month_names))
# Out:
# array([  0.   ,  20.125,  40.25 ,  60.375,  80.5  , 100.625, 120.75 ,
#        140.875])

# %%
plt.style.use('fivethirtyeight')

fig, ax = plt.subplots(figsize=(15,10))
ax.set_xticklabels(month_names)

plt.plot(election_cleaned.index, election_cleaned['w_biden'], label = 'Biden')
plt.plot(election_cleaned.index, election_cleaned['w_trump'], label = 'Trump')
plt.plot(election_cleaned.index, [50 for i in election_cleaned.index], '--' ,color = 'black')

plt.xlabel('Month (2020)')
plt.ylabel('Approval Percentage')
plt.title('2020 Presidential Candidate Approval Percentages')
plt.legend()

plt.savefig('../output/overall_approval.png', bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## October analysis

# %%
#month analysis from October1-November1
oct_nov = election_cleaned[election_cleaned.index >= '2020-10-01']

# %%
fig, ax = plt.subplots(figsize = (15,10))

plt.plot(oct_nov.index, oct_nov['w_biden'], label = 'Biden')
plt.plot(oct_nov.index, oct_nov['w_trump'], label = 'Trump')
plt.plot(oct_nov.index, [50]*len(oct_nov), '--', color = 'black')

plt.xticks(rotation = 90)
plt.xlabel('Date')
plt.ylabel('Approval Percentage')
plt.title('October 2020 Presidential Candidate Approval')
plt.legend()

plt.savefig('../output/oct_approval.png', bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## Twitter Figures

# %% [markdown]
# ### TFIDF scores for August 11

# %%
day1_biden = get_day_tfidf(score_df_biden, '2020-08-11')

day1_biden.head()
# Out:
#                    words     TFIDF
# 2020-08-11           win  0.231103
# 2020-08-11  kamalaharris  0.182757
# 2020-08-11           let  0.145437
# 2020-08-11       biggest  0.087172
# 2020-08-11        thanks  0.078693

# %%
fig, ax = plt.subplots(figsize = (15,10))

plt.bar(day1_biden.words[0:60], day1_biden.TFIDF[0:60], label = str("2020-08-11") + ' words')
plt.bar(day1_biden.words[0:15], day1_biden.TFIDF[0:15], color = 'green', label = str("2020-08-11") + ' top 15 words')

plt.margins(.02)
plt.xticks(rotation = 90)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 8)
plt.xlabel('Top 60 Words')
plt.ylabel('TFIDF Score')
plt.legend()

plt.savefig('../output/words_20200811.png', bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ### Keywords by polling results

# %%
## Election results August and later
elec_post_aug = election_cleaned[election_cleaned.index >= '2020-08-11']

# %%
fig, ax = plt.subplots(figsize = (15, 10))

plt.plot(elec_post_aug.index, elec_post_aug['w_biden'], label = 'Biden')
plt.plot(elec_post_aug.index, elec_post_aug['w_trump'], label = 'Trump')
plt.plot(elec_post_aug.index, [50]*len(elec_post_aug), '--', color = 'black')

plt.xticks(rotation = 90)
plt.xlabel('Date')
plt.ylabel('Approval Percentage')
plt.title('2020 Presidential Candidate Approval')
plt.legend()


## Add word labels to plot
for i in range(len(elec_post_aug)):
    
    largedelta = False
    
    if i > 0:
        largedelta = (np.abs(elec_post_aug['w_biden'][i] - elec_post_aug['w_biden'][i-1]) > 5)
        
    if largedelta:
        day = get_day_tfidf(score_df_biden, score_df_biden.index[i])
        label = day.sort_values("TFIDF", ascending = False).iloc[0]["words"]

        ax.annotate(label, (elec_post_aug.index[i], elec_post_aug['w_biden'][i] + 1), color='blue')

for k in range(len(elec_post_aug)):
    
    ## Shift to account for different start dates
    i = k + 0

    largedelta = False
    
    if i > 0:
        largedelta = (np.abs(elec_post_aug['w_trump'][i] - elec_post_aug['w_trump'][i-1]) > 5)
        
    if largedelta:
        day = get_day_tfidf(score_df_trump, score_df_trump.index[i])
        label = day.sort_values("TFIDF", ascending = False).iloc[0]["words"]

        ax.annotate(label, (elec_post_aug.index[k], elec_post_aug['w_trump'][k] - 1), color = 'darkred')
        
plt.savefig('../output/approval_words.png', bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ### Keywords by polling results (rolling averages)

# %%
## Calculate rolling averages for polling results
window = 7

running_avg_biden = movingaverage(elec_post_aug['w_biden'], window)
running_avg_trump = movingaverage(elec_post_aug['w_trump'], window)

# %%
## Manually select notable dates (days since start of August)
noteable_date_biden = [3, 7, 9, 12, 17, 19, 20, 22, 26, 32, 37, 39, 41, 46, 49, 50, 55, 57, 60, 62, 67]
noteable_date_trump = [3, 7, 9, 11, 13, 16, 20, 22, 27, 28, 31, 34, 38, 39, 44, 48, 50, 52, 55, 58, 61, 65, 67]

# %%
fig, ax = plt.subplots(figsize = (15,10))

## Remove ends of data to account for moving average
plt.plot(elec_post_aug.index[window//2:-((window-1)//2)], running_avg_biden, label='Biden')
plt.plot(elec_post_aug.index[window//2:-((window-1)//2)], running_avg_trump, label='Trump')
plt.plot(elec_post_aug.index[window//2:-((window-1)//2)], [50 for i in elec_post_aug.index[window//2:-((window-1)//2)]], color='black')

location = plticker.MultipleLocator(base=2.0)
ax.xaxis.set_major_locator(location)

plt.xticks(rotation = 90)
plt.xlabel('Date')
plt.ylabel('Approval Percentage Rolling Average')
plt.title('2020 Presidential Candidate Approval')
plt.legend()

for i in range(len(elec_post_aug)):
    if i in noteable_date_biden:
        day = get_day_tfidf(score_df_biden, score_df_biden.index[i])
        label = day.sort_values("TFIDF", ascending = False).iloc[0]["words"]

        ax.annotate(label, (elec_post_aug.index[i], running_avg_biden[i]), color='blue')
        
for i in range(len(elec_post_aug)):
    if i in noteable_date_trump:
        day = get_day_tfidf(score_df_trump, score_df_trump.index[i])
        label = day.sort_values("TFIDF", ascending = False).iloc[0]["words"]
        
        ax.annotate(label, (elec_post_aug.index[i], running_avg_trump[i]), color = 'darkred')

plt.savefig('../output/approval_words_ra.png', bbox_inches = 'tight')
plt.show()

# %%
#Bar chart of most relevant words each month for Biden
mos = ["August", "September", "October"]
n = 50
for i in range(3):
    fig, ax = plt.subplots(figsize=(15, 10))
    tfidf_list = score_df_biden_mo.iloc[i][0]
    width = 0.35
    heights = []
    names = []
    for j in range(n):
        heights.append(tfidf_list[j][1])
        names.append(tfidf_list[j][0])
    plt.bar(names, heights, width)
    plt.xticks(rotation=90)
    plt.title(mos[i] + " overall top " + str(n) + " words for Biden")
    plt.xlabel("Word")
    plt.ylabel("Relative word relevance")
    plt.savefig(f'../output/biden_{mos[i]}_top_{n}.png', bbox_inches = 'tight')
    plt.show()

# %%
#Bar chart of most relevant words each month for Trump
mos = ["August", "September", "October"]
n = 50
for i in range(3):
    fig, ax = plt.subplots(figsize=(15, 10))
    tfidf_list = score_df_trump_mo.iloc[i][0]
    width = 0.35
    heights = []
    names = []
    for j in range(n):
        heights.append(tfidf_list[j][1])
        names.append(tfidf_list[j][0])
    plt.bar(names, heights, width)
    plt.xticks(rotation=90)
    plt.title(mos[i] + " overall top " + str(n) + " words for Trump")
    plt.xlabel("Word")
    plt.ylabel("Relative word relevance")
    plt.savefig(f'../output/trump_{mos[i]}_top_{n}.png', bbox_inches = 'tight')
    plt.show()
