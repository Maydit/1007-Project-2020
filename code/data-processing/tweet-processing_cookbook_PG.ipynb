# %%
from datetime import datetime
from dateutil import parser

from nltk.corpus import stopwords
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import math
from collections import Counter
import numpy as np


import re

# %% [markdown]
# ### Import Data

# %%
joe_df = pd.read_csv('joe.csv', parse_dates=True)#,index_col='date')
joe_df['date_time']= pd.to_datetime(joe_df['date'])
joe_df['date']= joe_df['date_time'].dt.date
joe_df.head()
# Out:
#    Unnamed: 0                   id      conversation_id    created_at  \
# 0           0  1325885871875190784  1325885871875190784  1.604951e+12
# 1           1  1325880083618426881  1325880083618426881  1.604949e+12
# 2           2  1325873288711712769  1325873288711712769  1.604948e+12
# 3           3  1325870017401905152  1325870017401905152  1.604947e+12
# 4           4  1325842292444291072  1325842292444291072  1.604940e+12
#
#          date  timezone  place  \
# 0  2020-11-09      -500    NaN
# 1  2020-11-09      -500    NaN
# 2  2020-11-09      -500    NaN
# 3  2020-11-09      -500    NaN
# 4  2020-11-09      -500    NaN
#
#                                                tweet language hashtags  ...  \
# 0  The bottom line: I will spare no effort to tur...       en       []  ...
# 1  The challenge before us right now is still imm...       en       []  ...
# 2  My COVID-19 Transition Advisory Board will adv...       en       []  ...
# 3  Today, I have named a COVID-19 Transition Advi...       en       []  ...
# 4  I spent the morning with the co-chairs of my C...       en       []  ...
#
#   source  user_rt_id  user_rt retweet_id reply_to  retweet_date  translate  \
# 0    NaN         NaN      NaN        NaN       []           NaN        NaN
# 1    NaN         NaN      NaN        NaN       []           NaN        NaN
# 2    NaN         NaN      NaN        NaN       []           NaN        NaN
# 3    NaN         NaN      NaN        NaN       []           NaN        NaN
# 4    NaN         NaN      NaN        NaN       []           NaN        NaN
#
#   trans_src trans_dest           date_time
# 0       NaN        NaN 2020-11-09 14:40:00
# 1       NaN        NaN 2020-11-09 14:17:00
# 2       NaN        NaN 2020-11-09 13:50:00
# 3       NaN        NaN 2020-11-09 13:37:00
# 4       NaN        NaN 2020-11-09 11:46:50
#
# [5 rows x 40 columns]

# %% [markdown]
# ### Define Preprocessing Function

# %%
#remove urls
def remove_url(txt):
    return " ".join(re.sub("([^0-9A-Za-z \t])|(\w+:\/\/\S+)", "", txt).split())

#filter stop words
stop_words = set(stopwords.words('english'))

def remove_stop_words(txt_list):
    filtered_txt_list = []
    for word in txt_list:
        if word not in stop_words:
            filtered_txt_list.append(word)
    return(filtered_txt_list)

#compute TF
def computeTF(x):
    wordList= x[0]
    wordFreq =x[1]
    tfDict = {}
    bagOfWordsCount = len(wordList)
    for word, count in wordFreq.items():
        tfDict[word] = count / float(bagOfWordsCount)
    return Counter(tfDict)


#computer term_counter
def term_counter(txt_list):
    term_counts = {}
    for i in set(txt_list):
        term_counts[i] = txt_list.count(i)
    return(Counter(term_counts))

#return list of term counts for each tweet
def return_term_count_list(df, term_count_column = "term_count"):
    term_count_list = []
    for i in df[term_count_column]:
        term_count_list.append(dict(i))
    return(term_count_list)


#return copurs set for all tweets
def return_corpus_set(df, term_list_column = "term_list"):    
    tweet_corpus = []
    for i in df[term_list_column]:
        tweet_corpus += i
    corpus_set = set(tweet_corpus)
    return(corpus_set)

#computer IDF
def computeIDF(documents,corpus_set):
    N = len(documents)

    idfDict = dict.fromkeys(corpus_set, 0)
    for document in documents:
        for word, val in document.items():
            if val > 0:
                idfDict[word] += 1


    for word, val in idfDict.items():
        idfDict[word] = math.log(N / (float(val))) #smoothing?
    return(Counter(idfDict))

#computes TFIDF
def computeTFIDF(TF,idfs):
    tfidf = {}
    for word, val in TF.items():
        tfidf[word] = val * idfs[word]
    return(Counter(tfidf))

# %%
def TFIDF_processing(df, startdate = "August 11, 2020"):
    df = df[["id","date_time","date","tweet"]]

    
    #filter data frame:
    startdate = parser.parse(str(startdate))
    df = df[df["date_time"] > startdate]
    df['term_list'] = df['tweet'].apply(lambda x: remove_url(x))
    df['term_list'] = df['term_list'].apply(lambda x: x.lower().split())
    df['term_list'] = df['term_list'].apply(lambda x: remove_stop_words(x))
    
    #calc TFs
    df['term_count'] = df['term_list'].apply(lambda x: term_counter(x))
    df["TF"] = df[['term_list','term_count']].apply(computeTF,axis=1)
    
    #return corpus and doc list
    term_count_list_df = return_term_count_list(df)
    corpus_set_df = return_corpus_set(df)
    
    #calc IDF and  TF-IDF
    df_idf = computeIDF(term_count_list_df,corpus_set_df)
    df["TFIDF"] = df["TF"].apply(lambda x: computeTFIDF(x, df_idf))
    
    return(df, df_idf, corpus_set_df)

# %%
joe_df, joe_idf,joe_corpus = TFIDF_processing(joe_df)
joe_df
# Out:
#                        id           date_time        date  \
# 0     1325885871875190784 2020-11-09 14:40:00  2020-11-09
# 1     1325880083618426881 2020-11-09 14:17:00  2020-11-09
# 2     1325873288711712769 2020-11-09 13:50:00  2020-11-09
# 3     1325870017401905152 2020-11-09 13:37:00  2020-11-09
# 4     1325842292444291072 2020-11-09 11:46:50  2020-11-09
# ...                   ...                 ...         ...
# 1256  1293340421444124672 2020-08-11 20:16:00  2020-08-11
# 1257  1293280412144267264 2020-08-11 16:17:32  2020-08-11
# 1258  1293280411150217219 2020-08-11 16:17:32  2020-08-11
# 1259  1293215600680951810 2020-08-11 12:00:00  2020-08-11
# 1260  1293175334037262336 2020-08-11 09:20:00  2020-08-11
#
#                                                   tweet  \
# 0     The bottom line: I will spare no effort to tur...
# 1     The challenge before us right now is still imm...
# 2     My COVID-19 Transition Advisory Board will adv...
# 3     Today, I have named a COVID-19 Transition Advi...
# 4     I spent the morning with the co-chairs of my C...
# ...                                                 ...
# 1256  Let’s go win this, @KamalaHarris.  https://t.c...
# 1257  Back when Kamala was Attorney General, she wor...
# 1258  I have the great honor to announce that I’ve p...
# 1259  Don't forget that in the middle of this pandem...
# 1260  I promise you if I'm elected, I won't waste an...
#
#                                               term_list  \
# 0     [bottom, line, spare, effort, turn, pandemic, ...
# 1     [challenge, us, right, still, immense, growing...
# 2     [covid19, transition, advisory, board, advise,...
# 3     [today, named, covid19, transition, advisory, ...
# 4     [spent, morning, cochairs, covid19, council, d...
# ...                                                 ...
# 1256                      [lets, go, win, kamalaharris]
# 1257  [back, kamala, attorney, general, worked, clos...
# 1258  [great, honor, announce, ive, picked, kamalaha...
# 1259  [dont, forget, middle, pandemic, trump, admini...
# 1260  [promise, im, elected, wont, waste, time, gett...
#
#                                              term_count  \
# 0     {'line': 1, 'turn': 1, 'spare': 1, 'effort': 1...
# 1     {'right': 1, 'us': 1, 'challenge': 1, 'pandemi...
# 2     {'empathy': 1, 'science': 1, 'advisory': 1, 'e...
# 3     {'advisory': 1, 'plan': 1, 'public': 1, 'put':...
# 4     {'forward': 1, 'morning': 1, 'covid19': 1, 'di...
# ...                                                 ...
# 1256  {'kamalaharris': 1, 'win': 1, 'go': 1, 'lets': 1}
# 1257  {'lifted': 1, 'working': 1, 'beau': 1, 'closel...
# 1258  {'fearless': 1, 'great': 1, 'kamalaharris': 1,...
# 1259  {'middle': 1, 'build': 1, 'insurance': 1, 'try...
# 1260  {'stay': 1, 'bring': 1, 'done': 1, 'time': 1, ...
#
#                                                      TF  \
# 0     {'line': 0.14285714285714285, 'turn': 0.142857...
# 1     {'right': 0.09090909090909091, 'us': 0.0909090...
# 2     {'empathy': 0.058823529411764705, 'science': 0...
# 3     {'advisory': 0.04, 'plan': 0.04, 'public': 0.0...
# 4     {'forward': 0.0625, 'morning': 0.0625, 'covid1...
# ...                                                 ...
# 1256  {'kamalaharris': 0.25, 'win': 0.25, 'go': 0.25...
# 1257  {'lifted': 0.043478260869565216, 'working': 0....
# 1258  {'fearless': 0.058823529411764705, 'great': 0....
# 1259  {'middle': 0.04, 'build': 0.04, 'insurance': 0...
# 1260  {'stay': 0.034482758620689655, 'bring': 0.0344...
#
#                                                   TFIDF
# 0     {'line': 0.6429432866213801, 'turn': 0.7419643...
# 1     {'right': 0.3092718834255956, 'us': 0.19981981...
# 2     {'empathy': 0.35535576748804765, 'science': 0....
# 3     {'advisory': 0.24164192189187242, 'plan': 0.12...
# 4     {'forward': 0.29092210538605745, 'morning': 0....
# ...                                                 ...
# 1256  {'kamalaharris': 0.695737877318832, 'win': 0.8...
# 1257  {'lifted': 0.2802831806697815, 'working': 0.17...
# 1258  {'fearless': 0.4199800197626423, 'great': 0.25...
# 1259  {'middle': 0.16575712249643715, 'build': 0.121...
# 1260  {'stay': 0.15519320711550555, 'bring': 0.13807...
#
# [1261 rows x 8 columns]

# %%
def sum_normalize_collections(counter_list):
    counter_sum = Counter()
    for counter in counter_list:
        counter_sum += counter
    for k,v in counter_sum.items():
        counter_sum[k] = v/len(counter_list)
    return(counter_sum.most_common())

# %%
group_by_series = joe_df.groupby("date")["TFIDF"].apply(lambda x:x.to_list())
group_by_series
# Out:
# date
# 2020-08-11    [{'join': 0.2940618686100579, 'ever': 0.337384...
# 2020-08-12    [{'kamalaharris': 0.16370302995737224, 'called...
# 2020-08-13    [{'82': 3.56983016798246, 'days': 1.5661635753...
# 2020-08-14    [{'kamalaharris': 0.695737877318832, 'americas...
# 2020-08-15    [{'president': 0.21785772830962136, 'ready': 0...
#                                     ...
# 2020-11-04    [{'across': 0.12819222485363846, 'american': 0...
# 2020-11-05    [{'votes': 0.23251742898855932, 'counted': 0.4...
# 2020-11-06    [{'opponents': 1.6116282888512437, 'may': 1.00...
# 2020-11-07    [{'thank': 1.224641477721731, 'bottom': 2.0136...
# 2020-11-09    [{'line': 0.6429432866213801, 'turn': 0.741964...
# Name: TFIDF, Length: 90, dtype: object

# %%
score_df = pd.DataFrame(joe_df.groupby("date")["TFIDF"].apply(lambda x: sum_normalize_collections(x.to_list())))
score_df
# Out:
#                                                         TFIDF
# date
# 2020-08-11  [(win, 0.18158107361427933), (go, 0.1437825367...
# 2020-08-12  [(kamalaharris, 0.13117880488284), (worried, 0...
# 2020-08-13  [(82, 0.39664779644249554), (days, 0.174018175...
# 2020-08-14  [(story, 0.2673950433368432), (social, 0.23918...
# 2020-08-15  [(know, 0.11188818823996126), (vice, 0.0985908...
# ...                                                       ...
# 2020-11-04  [(count, 0.145789478930796), (victory, 0.13931...
# 2020-11-05  [(counted, 0.29949649183368193), (faith, 0.121...
# 2020-11-06  [(opponents, 0.2302326126930348), (enemies, 0....
# 2020-11-07  [(bottom, 0.12585516765201687), (heart, 0.1175...
# 2020-11-09  [(pandemic, 0.20908944553767106), (spare, 0.20...
#
# [90 rows x 1 columns]

# %%
# Document Vectorization
def TFIDF_vecorization(df,corpus):
    D = np.zeros((len(df), len(corpus)))

    for i,tfidf in enumerate(df["TFIDF"]):
        for term in tfidf:
            ind = (list(corpus)).index(term)
            D[i][ind] = tfidf[term]
    return(D)

# %% [markdown]
# ### Next Steps:
# #### clean data:
# -handle punctuation/concatenated words (first pass done)
# -may pick specific work fileter? ( )
# #### average TIDF scores by day
# -vectorize TIDF dictionaries ? (wrote a function, not really ideal)
#
# -sum TF-IDF vector with in a day, normalize to number of tweets with in that day (done)
#
# -Return top 50 scores for that done ( )
